# %%
import os
import sys
sys.path.insert(0, '../gofher')

import itertools
from collections import defaultdict

from sparcfire import get_gofher_params_for_fixed_ref_band, read_sparcfire_galaxy_csv
from galaxy import galaxy, construct_band_pair_key
from sdss import SDSS_BANDS_IN_ORDER, visualize_sdss, create_sdss_csv
from spin_parity import read_spin_parity_galaxies_label_from_csv
from gofher import run_gofher_on_galaxy_with_fixed_gofher_parameters, run_gofher_on_galaxy_with_fixed_center_only, run_gofher_on_galaxy_with_sparcfire_center_inital_guess
from file_helper import write_csv
from p_act import evaluate_p_act

# %%
blur_sdss_fits_folder = "E:\\grad_school\\research\\spin_parity_blurring\\sdss_output"
blur_sdss_folder = "E:\\grad_school\\research\\spin_parity_blurring\\sparcfire_sdss_output"

dark_side_path = "C:\\Users\\school\\Desktop\\github\\spin-parity-catalog\\table_info\\csv_format_of_table\\"

fixed_ref_band_folder = "C:\\Users\\school\\Desktop\\cross_id\\sdss_mosaic_construction\\sdss_ref_band"
csv_base_output_dir = "E:\\grad_school\\research\\spin_parity_blurring\\gofher_sdss_output_stats_code_dark_side"

# %%
generate_visualization = True
generate_csv = False

# %%
use_code_dark_side = True

# %%
#run_types = ['inital_guess'] #,'fixed_center' rs doesn't matter
run_types = ['sparcfire']
bulge_disk_rs = [0.125]

##run_types = ['sparcfire','inital_guess'] #,'fixed_center' rs doesn't matter
##bulge_disk_rs = [0.5,0.25,0.125]
#run_types = ['fixed_center']
#bulge_disk_rs = [0.5]

# %%
#blurring params to run on:
#sn_list = [8, 16, 32, 64, 128, 256]
#psf_list = [4.0,5.6, 8.0, 11.3, 16.0, 22.6, 32.0, 45.2, 64.0, 90.5, 128.0]

#sn_list = [0.5,0.25,0.125,0.0625]
#psf_list = [4.0,5.6, 8.0, 11.3, 16.0, 22.6, 32.0, 45.2, 64.0, 90.5, 128.0, 181.0, 256.0]

sn_list = [0.5,0.25,0.125,0.0625,8, 16, 32, 64, 128, 256]
psf_list = [4.0,5.6, 8.0, 11.3, 16.0, 22.6, 32.0, 45.2, 64.0, 90.5, 128.0]

#datasets = {"train":["table2"],"test":["table4","table5"],"eval":["table3"]}
datasets = {"train":["table2"]}#,"test":["table4","table5"]}
#datasets = {"eval":["table3"]}
table_list = sum(datasets.values(), []) #flatten list of list of values

# %%
def get_blur_folder(the_sn,the_psf):
    return "psf_{}_background_{}".format(str(the_psf),str(the_sn))

def get_fits_path(the_sn,the_psf):
    return lambda table_name,name,band: os.path.join(blur_sdss_fits_folder,get_blur_folder(the_sn,the_psf),table_name,name,"{}_{}.fits".format(name,band))

def get_galaxy_list(table_name,the_sn,the_psf):
    return os.listdir(os.path.join(blur_sdss_fits_folder,get_blur_folder(the_sn,the_psf),table_name))

def get_dark_side_csv_path(table_name):
    return os.path.join(dark_side_path,"table_{}.csv".format(table_name.strip()[-1]))

def get_sparcfire_galaxy_csv_path(table_name,the_sn,the_psf):
    return os.path.join(blur_sdss_folder,get_blur_folder(the_sn,the_psf),table_name,"G.out","galaxy.csv")

def get_ref_band_path(table_name):
    return os.path.join(fixed_ref_band_folder,"{}.txt".format(table_name))

def get_csv_output_path(dataset_name,the_sn,the_psf,the_r,the_type):
    r_string = str(the_r).replace('.','')
    if the_type != 'fixed_center':
        folder_dir = "{}_r_{}".format(the_type,r_string)
    else:
        folder_dir = the_type
    file_name = "{}_{}.csv".format(get_blur_folder(the_sn,the_psf),dataset_name)
    return os.path.join(csv_base_output_dir,folder_dir,file_name)

def get_visualization_dir_output_path(dataset_name,the_sn,the_psf,the_r,the_type):
    r_string = str(the_r).replace('.','')
    if the_type != 'fixed_center':
        folder_dir = "{}_r_{}".format(the_type,r_string)
    else:
        folder_dir = the_type
    add_folder_name = "{}_{}".format(get_blur_folder(the_sn,the_psf),dataset_name)
    return os.path.join(csv_base_output_dir,folder_dir,add_folder_name)

# %%
def get_ref_band_dict_for_table(table_name):
    ref_band_dict = dict()

    first = True
    with open(get_ref_band_path(table_name)) as f:
        for line in f.readlines():
            if first:
                first = False
            else:
                to_parse = line.strip().rsplit(" ",1)
                if len(to_parse) != 2: continue

                ref_band_dict[to_parse[0]] = to_parse[1]
    return ref_band_dict


def get_ref_band_and_dark_side_dicts_for_folders(the_folders):
    ref_band_dict = dict()
    dark_side_dict = dict()
    
    for folder in the_folders:
        for (k,v) in get_ref_band_dict_for_table(folder).items():
            ref_band_dict[k] = v
        if use_code_dark_side:
            csv_code_folder = "E:\\grad_school\\research\\spin_parity_blurring\\gofher_code_output_dark_side\\sparcfire_r_0125\\{}.csv".format(folder)
            first = True
            with open(csv_code_folder) as f:
                for line in f.readlines():
                    if first:
                        first = False
                    else:
                        to_parse = line.strip().split(",")
                        if len(to_parse) != 2: continue
                        dark_side_dict[to_parse[0]] = to_parse[1]
        else:
            for (k,v) in read_spin_parity_galaxies_label_from_csv(get_dark_side_csv_path(folder)).items():
                dark_side_dict[k] = v
    
    return ref_band_dict, dark_side_dict

def get_galaxy_to_folder_dict(the_folders,the_sn,the_psf):
    galaxy_to_folder_dict = dict()

    for each_folder in the_folders:
        for each_galaxy in get_galaxy_list(each_folder,the_sn,the_psf):
            galaxy_to_folder_dict[each_galaxy] = each_folder

    return galaxy_to_folder_dict

def get_sparcfire_for_folders(the_folders, sn, psf):
    sparcfire_bands = dict()
    for each_folder in the_folders:
        the_pa = get_sparcfire_galaxy_csv_path(each_folder,sn, psf)
        #print(the_pa)
        for (k,v) in read_sparcfire_galaxy_csv(the_pa).items():
            sparcfire_bands[k] = v

    return sparcfire_bands

# %%
def create_blur_csv(gals,the_band_pairs,csv_path):
    correct_count = defaultdict(int)
    no_vote_count = defaultdict(int)
    incorrect_count = defaultdict(int)


    """create an csv containing the information from gofher of the given galaxies"""
    #Construct CSV header:
    csv_column_headers = ['name','dark_side_label','pos_side_label','neg_side_label','ref_band','encounted_sersic_error','table_name']
    if use_code_dark_side:
        csv_column_headers[1] = "gofher_derived_"+csv_column_headers[1]
    #per_band_column_headers = ['label','score']
    per_band_column_headers = ['pos_side_mean','pos_side_std','neg_side_mean','neg_side_std','D','P','label','score']

    for band_pair in the_band_pairs:
        band_pair_key = construct_band_pair_key(band_pair[0],band_pair[1])
        csv_column_headers.extend(list(map(lambda x: "{}_{}".format(band_pair_key,x),per_band_column_headers)))

    csv_column_headers.extend(['vote_count','vote_score'])
    
    #Construct CSV rows:
    rows = []
    for gal in gals:
        if not isinstance(gal,galaxy): continue

        the_row = [gal.name,gal.dark_side,gal.pos_side_label,gal.neg_side_label,gal.ref_band,str(gal.encountered_sersic_fit_error),gal.folder]
        for band_pair in the_band_pairs:
            band_pair_key = construct_band_pair_key(band_pair[0],band_pair[1])
            if band_pair_key not in gal.band_pairs: 
                the_row.extend(['MISSING',0])
                continue
            the_band_pair = gal.get_band_pair(band_pair_key)

            the_row.extend([the_band_pair.pos_fit_norm_mean,the_band_pair.pos_fit_norm_std,
                            the_band_pair.neg_fit_norm_mean,the_band_pair.neg_fit_norm_std,
                            the_band_pair.d_stat, the_band_pair.p_value,
                            the_band_pair.classification_label,
                            the_band_pair.classification_score])
            
            #the_row.extend([the_band_pair.classification_label,
            #                the_band_pair.classification_score])
            
            if the_band_pair.classification_score == 1:
                correct_count[band_pair_key+"_score"] += 1
            elif the_band_pair.classification_score == -1:
                incorrect_count[band_pair_key+"_score"] += 1
            else:
                no_vote_count[band_pair_key+"_score"] += 1
        
        the_row.extend([gal.cumulative_classification_vote_count,gal.cumulative_score])
        rows.append(the_row)

        if gal.cumulative_score == 1:
            correct_count["vote_score"] += 1
        elif gal.cumulative_score == -1:
            incorrect_count["vote_score"] += 1
        else:
            no_vote_count["vote_score"] += 1

    the_score_keys = list(filter(lambda x: "score" in x,csv_column_headers))

    correct_count_row = ['']*len(csv_column_headers)
    correct_count_row[0] = 'CORRECT_COUNT'

    no_vote_count_row = ['']*len(csv_column_headers)
    no_vote_count_row[0] = 'NO_VOTE_COUNT'

    incorrect_count_row = ['']*len(csv_column_headers)
    incorrect_count_row[0] = 'INCORRECT_COUNT'

    accuracy_row = ['']*len(csv_column_headers)
    accuracy_row[0] = 'ACCURACY'

    for each_score_key in the_score_keys:
        row_ind = csv_column_headers.index(each_score_key)

        correct = 0
        no_vote = 0
        incorrect = 0
        accuracy = 100.0

        if each_score_key in correct_count:
            correct = correct_count[each_score_key]

        if each_score_key in no_vote_count:
            no_vote = no_vote_count[each_score_key]

        if each_score_key in incorrect_count:
            incorrect = incorrect_count[each_score_key]

        if (correct+incorrect) > 0:
            accuracy = (correct/(correct+incorrect)) * 100.0

        correct_count_row[row_ind] = correct
        no_vote_count_row[row_ind] = no_vote
        incorrect_count_row[row_ind] = incorrect
        accuracy_row[row_ind] = accuracy

    rows.extend([correct_count_row,no_vote_count_row,incorrect_count_row,accuracy_row])
    write_csv(csv_path,csv_column_headers,rows)

# %%
def get_visualization_additional_str(the_sn,the_psf,the_r,the_type):
    return " {} r={} (psf={}, sn={})".format(the_type,the_r,the_psf,the_sn)

# %%
def run_on_blurred_images(name, fits_path, sparcfire_bands, the_ref_band, table_name, dark_side_label='', bulge_disk_r=1.0, run_type = '', vis_path ='', add_vis_string=''):
    the_gal = galaxy(name,dark_side_label)

    for band in SDSS_BANDS_IN_ORDER:
       if not os.path.exists(fits_path(table_name,name,band)): continue
       the_gal.construct_band(band,fits_path(table_name,name,band))

    the_sparcfire_derived_params = get_gofher_params_for_fixed_ref_band(sparcfire_bands, the_ref_band, bulge_disk_r=bulge_disk_r)
    if the_sparcfire_derived_params == None: return None

    the_gal.ref_band = the_ref_band
    the_band_pairs = list(itertools.combinations(SDSS_BANDS_IN_ORDER, 2))

    the_gal.folder = table_name

    run_type = run_type.strip().lower() 
    if run_type == 'inital_guess':
        the_gal = run_gofher_on_galaxy_with_sparcfire_center_inital_guess(the_gal,the_band_pairs,the_sparcfire_derived_params)
    elif run_type == 'fixed_center':
        the_gal = run_gofher_on_galaxy_with_fixed_center_only(the_gal,the_band_pairs,the_sparcfire_derived_params)
    else:
        the_gal = run_gofher_on_galaxy_with_fixed_gofher_parameters(the_gal,the_band_pairs,the_sparcfire_derived_params)

    if generate_visualization and vis_path != '':
        visualize_sdss(the_gal,vis_path, add_vis_string)
        
    return the_gal #uncomment for csv

# %%
def run_all_settings():
    for each_dataset in datasets:
        ref_band_dict, dark_side_dict = get_ref_band_and_dark_side_dicts_for_folders(list(datasets[each_dataset]))
        print(dark_side_dict)
        j = 1
        for sn in sn_list:
            for psf in psf_list:
                print(" ",j,get_blur_folder(sn,psf))
                galaxy_to_table_dict =  get_galaxy_to_folder_dict(list(datasets[each_dataset]),sn,psf)
                #print(get_sparcfire_for_folders(list(datasets[each_dataset]), sn, psf))
                sparcfire_csv_dict = get_sparcfire_for_folders(list(datasets[each_dataset]), sn, psf)

                #r = 0.125
                #run_type = 'inital_guess'

                for r in bulge_disk_rs:
                    for run_type in run_types:
                        print("     ",r,run_type)
                        csv_output_path = get_csv_output_path(each_dataset,sn,psf,r,run_type)
                        #if os.path.exists(csv_output_path):
                        #    continue

                        vis_folder = get_visualization_dir_output_path(each_dataset,sn,psf,r,run_type)
                        #if os.path.exists(vis_folder):
                        #    j += 1
                        #    continue
                        if generate_visualization and not os.path.exists(vis_folder):
                            os.makedirs(vis_folder)

                        i = 1
                        the_gals = []
                        for name in galaxy_to_table_dict.keys():

                            if name.lower() != "NGC2775".lower() and name.lower() != "NGC157".lower(): 
                                #print(name,"skip")
                                continue
                            #else:
                            #    print("here")

                            print("     ",i,name)
                            if name not in sparcfire_csv_dict: continue
                            if name not in ref_band_dict: continue
                            if name not in galaxy_to_table_dict: continue
                            if name not in dark_side_dict: continue

                            try:
                                vis_path = os.path.join(vis_folder,"{}.png".format(name))
                                #if os.path.exists(vis_path): continue #to skip rerun
                                add_vis_string = get_visualization_additional_str(sn,psf,r,run_type)
                                print(vis_path)
                                current_gal = run_on_blurred_images(name,get_fits_path(sn,psf),sparcfire_csv_dict[name],ref_band_dict[name],galaxy_to_table_dict[name],dark_side_dict[name],r,run_type,vis_path,add_vis_string) #uncomment for csv
                                #current_gal = run_on_blurred_images(name,get_fits_path(sn,psf),sparcfire_csv_dict[name],ref_band_dict[name],galaxy_to_table_dict[name],dark_side_dict[name],r,run_type,'',add_vis_string)
                                #print('pact')
                                #evaluate_p_act(current_gal,SDSS_BANDS_IN_ORDER)
                                #run_on_blurred_images(name,get_fits_path(sn,psf),sparcfire_csv_dict[name],ref_band_dict[name],galaxy_to_table_dict[name],dark_side_dict[name],r,run_type,vis_path,add_vis_string)

                                if not isinstance(current_gal,galaxy): continue #uncomment for csv
                                the_gals.append(current_gal) #uncomment for csv
                            except Exception as e:
                                print("error")
                                print("         ",e)
                                #return
                            i += 1
                            #return


                        
                        #uncomment for csv
                        if generate_csv:
                            base_dir = os.path.dirname(csv_output_path)
                            if not os.path.exists(base_dir):
                                os.makedirs(base_dir)
                        
                            the_band_pairs = list(itertools.combinations(SDSS_BANDS_IN_ORDER, 2)) #SDSS
                        
                            print(the_gals)
                            create_blur_csv(the_gals,the_band_pairs,csv_output_path)
                            #create_sdss_csv(the_gals,the_band_pairs,csv_output_path)
                        j += 1
                        #return

# %%
run_all_settings()
# Out:
# {'IC1683': 'W', 'IC1755': 'NE', 'IC2101': 'NE', 'IC5376': 'W', 'NGC1035': 'NE', 'NGC1056': 'SW', 'NGC1084': 'NW', 'NGC1093': 'N', 'NGC157': 'SE', 'NGC1667': 'E', 'NGC169': 'N', 'NGC2347': 'E', 'NGC2410': 'NW', 'NGC2639': 'NE', 'NGC2683': 'NW', 'NGC2742': 'S', 'NGC2775': 'W', 'NGC2841': 'NE', 'NGC2903': 'NW', 'NGC3160': 'SW', 'NGC3198': 'SE', 'NGC3227': 'SW', 'NGC3310': 'E', 'NGC3368': 'SW', 'NGC3521': 'W', 'NGC3623': 'E', 'NGC3627': 'E', 'NGC3646': 'NW', 'NGC3672': 'E', 'NGC3675': 'E', 'NGC3718': 'NW', 'NGC3815': 'N', 'NGC3900': 'E', 'NGC3949': 'NE', 'NGC4062': 'S', 'NGC4088': 'SE', 'NGC4293': 'S', 'NGC4310': 'W', 'NGC4414': 'E', 'NGC4424': 'N', 'NGC4450': 'E', 'NGC4451': 'W', 'NGC4501': 'NE', 'NGC4527': 'NW', 'NGC4569': 'W', 'NGC4580': 'SW', 'NGC4625': 'W', 'NGC4632': 'NW', 'NGC4651': 'S', 'NGC4666': 'SE', 'NGC4698': 'SW', 'NGC4826': 'N', 'NGC5005': 'N', 'NGC5055': 'S', 'NGC5248': 'SW', 'NGC5303': 'S', 'NGC5395': 'W', 'NGC5448': 'S', 'NGC5635': 'SE', 'NGC5678': 'W', 'NGC5692': 'NW', 'NGC5949': 'SW', 'NGC5980': 'W', 'NGC6015': 'NW', 'NGC6106': 'SW', 'NGC6132': 'NE', 'NGC615': 'E', 'NGC6181': 'W', 'NGC6186': 'NW', 'NGC6207': 'E', 'NGC6394': 'NW', 'NGC6978': 'SW', 'NGC7311': 'E', 'NGC7331': 'W', 'NGC7364': 'SE', 'NGC7466': 'SE', 'NGC7479': 'W', 'NGC7536': 'NW', 'NGC7541': 'S', 'NGC7591': 'E', 'NGC7608': 'E', 'NGC7625': 'SE', 'NGC7631': 'N', 'NGC772': 'SW', 'NGC7738': 'NW', 'NGC7782': 'W', 'NGC7787': 'S', 'UGC10384': 'S', 'UGC1057': 'SW', 'UGC10972': 'NW', 'UGC11792': 'W', 'UGC12519': 'NE', 'UGC148': 'N', 'UGC1938': 'SW', 'UGC2405': 'E', 'UGC36': 'W', 'UGC3944': 'SW', 'UGC3969': 'NE', 'UGC4132': 'SE', 'UGC5359': 'S', 'UGC5396': 'NE', 'UGC5598': 'SE', 'UGC7145': 'NE', 'UGC7901': 'S', 'UGC9873': 'NE', 'UGC9892': 'S'}
#   1 psf_4.0_background_0.5
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_0.5_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_0.5_train\NGC2775.png
#   2 psf_5.6_background_0.5
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_0.5_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_0.5_train\NGC2775.png
#   3 psf_8.0_background_0.5
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_0.5_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_0.5_train\NGC2775.png
#   4 psf_11.3_background_0.5
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_0.5_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_0.5_train\NGC2775.png
#   5 psf_16.0_background_0.5
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_0.5_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_0.5_train\NGC2775.png
#   6 psf_22.6_background_0.5
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_0.5_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_0.5_train\NGC2775.png
#   7 psf_32.0_background_0.5
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_0.5_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_0.5_train\NGC2775.png
#   8 psf_45.2_background_0.5
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_0.5_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_0.5_train\NGC2775.png
#   9 psf_64.0_background_0.5
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_0.5_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_0.5_train\NGC2775.png
#   10 psf_90.5_background_0.5
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_0.5_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_0.5_train\NGC2775.png
#   11 psf_128.0_background_0.5
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_0.5_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_0.5_train\NGC2775.png
#   12 psf_4.0_background_0.25
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_0.25_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_0.25_train\NGC2775.png
#   13 psf_5.6_background_0.25
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_0.25_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_0.25_train\NGC2775.png
#   14 psf_8.0_background_0.25
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_0.25_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_0.25_train\NGC2775.png
#   15 psf_11.3_background_0.25
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_0.25_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_0.25_train\NGC2775.png
#   16 psf_16.0_background_0.25
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_0.25_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_0.25_train\NGC2775.png
#   17 psf_22.6_background_0.25
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_0.25_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_0.25_train\NGC2775.png
#   18 psf_32.0_background_0.25
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_0.25_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_0.25_train\NGC2775.png
#   19 psf_45.2_background_0.25
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_0.25_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_0.25_train\NGC2775.png
#   20 psf_64.0_background_0.25
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_0.25_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_0.25_train\NGC2775.png
#   21 psf_90.5_background_0.25
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_0.25_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_0.25_train\NGC2775.png
#   22 psf_128.0_background_0.25
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_0.25_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_0.25_train\NGC2775.png
#   23 psf_4.0_background_0.125
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_0.125_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_0.125_train\NGC2775.png
#   24 psf_5.6_background_0.125
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_0.125_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_0.125_train\NGC2775.png
#   25 psf_8.0_background_0.125
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_0.125_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_0.125_train\NGC2775.png
#   26 psf_11.3_background_0.125
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_0.125_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_0.125_train\NGC2775.png
#   27 psf_16.0_background_0.125
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_0.125_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_0.125_train\NGC2775.png
#   28 psf_22.6_background_0.125
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_0.125_train\NGC157.png
# error
#           zero-size array to reduction operation minimum which has no identity
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_0.125_train\NGC2775.png
#   29 psf_32.0_background_0.125
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_0.125_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_0.125_train\NGC2775.png
#   30 psf_45.2_background_0.125
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_0.125_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_0.125_train\NGC2775.png
#   31 psf_64.0_background_0.125
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_0.125_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_0.125_train\NGC2775.png
#   32 psf_90.5_background_0.125
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_0.125_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_0.125_train\NGC2775.png
#   33 psf_128.0_background_0.125
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_0.125_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_0.125_train\NGC2775.png
#   34 psf_4.0_background_0.0625
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_0.0625_train\NGC157.png
# error
#           zero-size array to reduction operation minimum which has no identity
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_0.0625_train\NGC2775.png
#   35 psf_5.6_background_0.0625
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_0.0625_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_0.0625_train\NGC2775.png
#   36 psf_8.0_background_0.0625
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_0.0625_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_0.0625_train\NGC2775.png
#   37 psf_11.3_background_0.0625
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_0.0625_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_0.0625_train\NGC2775.png
#   38 psf_16.0_background_0.0625
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_0.0625_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_0.0625_train\NGC2775.png
#   39 psf_22.6_background_0.0625
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_0.0625_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_0.0625_train\NGC2775.png
#   40 psf_32.0_background_0.0625
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_0.0625_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_0.0625_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   41 psf_45.2_background_0.0625
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_0.0625_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_0.0625_train\NGC2775.png
#   42 psf_64.0_background_0.0625
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_0.0625_train\NGC157.png
# error
#           zero-size array to reduction operation minimum which has no identity
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_0.0625_train\NGC2775.png
#   43 psf_90.5_background_0.0625
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_0.0625_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_0.0625_train\NGC2775.png
#   44 psf_128.0_background_0.0625
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_0.0625_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_0.0625_train\NGC2775.png
#   45 psf_4.0_background_8
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_8_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_8_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   46 psf_5.6_background_8
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_8_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_8_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   47 psf_8.0_background_8
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_8_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_8_train\NGC2775.png
#   48 psf_11.3_background_8
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_8_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_8_train\NGC2775.png
#   49 psf_16.0_background_8
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_8_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_8_train\NGC2775.png
#   50 psf_22.6_background_8
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_8_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_8_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   51 psf_32.0_background_8
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_8_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_8_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   52 psf_45.2_background_8
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_8_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_8_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   53 psf_64.0_background_8
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_8_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_8_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   54 psf_90.5_background_8
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_8_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_8_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   55 psf_128.0_background_8
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_8_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_8_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   56 psf_4.0_background_16
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_16_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_16_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   57 psf_5.6_background_16
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_16_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_16_train\NGC2775.png
#   58 psf_8.0_background_16
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_16_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_16_train\NGC2775.png
#   59 psf_11.3_background_16
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_16_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_16_train\NGC2775.png
#   60 psf_16.0_background_16
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_16_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_16_train\NGC2775.png
#   61 psf_22.6_background_16
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_16_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_16_train\NGC2775.png
#   62 psf_32.0_background_16
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_16_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_16_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   63 psf_45.2_background_16
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_16_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_16_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   64 psf_64.0_background_16
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_16_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_16_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   65 psf_90.5_background_16
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_16_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_16_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   66 psf_128.0_background_16
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_16_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_16_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   67 psf_4.0_background_32
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_32_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_32_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   68 psf_5.6_background_32
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_32_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_32_train\NGC2775.png
#   69 psf_8.0_background_32
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_32_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_32_train\NGC2775.png
#   70 psf_11.3_background_32
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_32_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_32_train\NGC2775.png
#   71 psf_16.0_background_32
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_32_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_32_train\NGC2775.png
#   72 psf_22.6_background_32
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_32_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_32_train\NGC2775.png
#   73 psf_32.0_background_32
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_32_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_32_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   74 psf_45.2_background_32
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_32_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_32_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   75 psf_64.0_background_32
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_32_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_32_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   76 psf_90.5_background_32
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_32_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_32_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   77 psf_128.0_background_32
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_32_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_32_train\NGC2775.png
#   78 psf_4.0_background_64
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_64_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_64_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   79 psf_5.6_background_64
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_64_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_64_train\NGC2775.png
#   80 psf_8.0_background_64
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_64_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_64_train\NGC2775.png
#   81 psf_11.3_background_64
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_64_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_64_train\NGC2775.png
#   82 psf_16.0_background_64
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_64_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_64_train\NGC2775.png
#   83 psf_22.6_background_64
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_64_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_64_train\NGC2775.png
#   84 psf_32.0_background_64
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_64_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_64_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   85 psf_45.2_background_64
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_64_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_64_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   86 psf_64.0_background_64
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_64_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_64_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   87 psf_90.5_background_64
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_64_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_64_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   88 psf_128.0_background_64
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_64_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_64_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   89 psf_4.0_background_128
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_128_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_128_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   90 psf_5.6_background_128
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_128_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_128_train\NGC2775.png
#   91 psf_8.0_background_128
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_128_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_128_train\NGC2775.png
#   92 psf_11.3_background_128
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_128_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_128_train\NGC2775.png
#   93 psf_16.0_background_128
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_128_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_128_train\NGC2775.png
#   94 psf_22.6_background_128
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_128_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_128_train\NGC2775.png
#   95 psf_32.0_background_128
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_128_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_128_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   96 psf_45.2_background_128
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_128_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_128_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   97 psf_64.0_background_128
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_128_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_128_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   98 psf_90.5_background_128
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_128_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_128_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   99 psf_128.0_background_128
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_128_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_128_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   100 psf_4.0_background_256
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_256_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_4.0_background_256_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   101 psf_5.6_background_256
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_256_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_5.6_background_256_train\NGC2775.png
#   102 psf_8.0_background_256
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_256_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_8.0_background_256_train\NGC2775.png
#   103 psf_11.3_background_256
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_256_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_11.3_background_256_train\NGC2775.png
#   104 psf_16.0_background_256
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_256_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_16.0_background_256_train\NGC2775.png
#   105 psf_22.6_background_256
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_256_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_22.6_background_256_train\NGC2775.png
#   106 psf_32.0_background_256
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_256_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_32.0_background_256_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   107 psf_45.2_background_256
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_256_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_45.2_background_256_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   108 psf_64.0_background_256
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_256_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_64.0_background_256_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   109 psf_90.5_background_256
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_256_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_90.5_background_256_train\NGC2775.png
# error
#           zero-size array to reduction operation minimum which has no identity
#   110 psf_128.0_background_256
#       0.125 sparcfire
#       1 NGC157
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_256_train\NGC157.png
#       2 NGC2775
# E:\grad_school\research\spin_parity_blurring\gofher_sdss_output_stats_code_dark_side\sparcfire_r_0125\psf_128.0_background_256_train\NGC2775.png
